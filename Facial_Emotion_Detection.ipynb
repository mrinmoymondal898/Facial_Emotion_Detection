# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os

DATA_DIR = "/content/drive/MyDrive/3RD_SEM_PROJ/image/images"
folders = os.listdir(DATA_DIR)
print(folders)
# Out:
# ['9', '18', '5', '14', '4', '0', '3', '13', '11', '2', '7', '15', '6', '8', '10', '16', '1', '17', '12']

# %%
EMOTIONS = ['Anger', 'Contempt', 'Disgust', 'Fear', 'Happy', 'Neutral', 'Sad', 'Surprised']
IMG_SIZE = 48

# %%
import cv2
import numpy as np
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import tensorflow as tf
from tensorflow.keras import layers, models

# %%
def load_data():
    images = []
    labels = []

    for emotion_label, emotion in enumerate(EMOTIONS):
        emotion_dir = os.path.join(DATA_DIR, str(emotion_label))
        if os.path.isdir(emotion_dir):
            for img_file in os.listdir(emotion_dir):
                img_path = os.path.join(emotion_dir, img_file)
                img_array = cv2.imread(img_path, cv2.IMREAD_GRAYSCALE)
                img_resized = cv2.resize(img_array, (IMG_SIZE, IMG_SIZE))
                images.append(img_resized)
                labels.append(emotion_label)
        else:
            print(f"Directory not found for emotion {emotion}: {emotion_dir}")

    return np.array(images), np.array(labels)

# Load the data
images, labels = load_data()


# Split data into train and test sets
X_train, X_test, y_train, y_test = train_test_split(images, labels, test_size=0.2, random_state=42)

# Normalize the pixel values
X_train = X_train / 255.0
X_test = X_test / 255.0

# Reshape data for CNN input
X_train = X_train.reshape(-1, IMG_SIZE, IMG_SIZE, 1)
X_test = X_test.reshape(-1, IMG_SIZE, IMG_SIZE, 1)

# %%
print("Number of images:", len(images))
print("Shape of images array:", images.shape)
print("Number of labels:", len(labels))

# Print sample images and their corresponding labels
import matplotlib.pyplot as plt

plt.figure(figsize=(20, 20))
for i in range(25):
    plt.subplot(5, 5, i + 1)
    plt.imshow(images[i], cmap='gray')
    plt.title(EMOTIONS[labels[i]])
    plt.axis('off')
plt.show()
# Out:
# Number of images: 64
# Shape of images array: (64, 48, 48)
# Number of labels: 64

# %%
datagen = ImageDataGenerator(
    rotation_range=10,
    zoom_range=0.1,
    width_shift_range=0.1,
    height_shift_range=0.1,
    horizontal_flip=True
)
datagen.fit(X_train)

# %%
model = models.Sequential([
    layers.Conv2D(64, (3, 3), activation='relu', input_shape=(IMG_SIZE, IMG_SIZE, 1)),
    layers.MaxPooling2D(2, 2),
    layers.Conv2D(128, (3, 3), activation='relu'),
    layers.MaxPooling2D(2, 2),
    layers.Conv2D(128, (3, 3), activation='relu'),
    layers.MaxPooling2D(2, 2),
    layers.Flatten(),
    layers.Dense(128, activation='relu'),
    layers.Dropout(0.5),  # Dropout layer to prevent overfitting
    layers.Dense(len(EMOTIONS), activation='softmax')
])

# Compile the model
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

model.summary()
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/convolutional/base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d_9 (Conv2D)               │ (None, 46, 46, 64)     │           640 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_9 (MaxPooling2D)  │ (None, 23, 23, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_10 (Conv2D)              │ (None, 21, 21, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_10 (MaxPooling2D) │ (None, 10, 10, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_11 (Conv2D)              │ (None, 8, 8, 128)      │       147,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_11 (MaxPooling2D) │ (None, 4, 4, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_3 (Flatten)             │ (None, 2048)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_6 (Dense)                 │ (None, 128)            │       262,272 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_7 (Dense)                 │ (None, 8)              │         1,032 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 485,384 (1.85 MB)
#  Trainable params: 485,384 (1.85 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Train the model
history = model.fit(datagen.flow(X_train, y_train, batch_size=32), epochs=50, validation_data=(X_test, y_test))
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 3s 487ms/step - accuracy: 0.1436 - loss: 2.0870 - val_accuracy: 0.1538 - val_loss: 2.0766
# Epoch 2/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 335ms/step - accuracy: 0.2315 - loss: 2.0255 - val_accuracy: 0.1538 - val_loss: 2.0781
# Epoch 3/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 228ms/step - accuracy: 0.1097 - loss: 2.0855 - val_accuracy: 0.3077 - val_loss: 2.0256
# Epoch 4/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 326ms/step - accuracy: 0.1527 - loss: 2.0198 - val_accuracy: 0.2308 - val_loss: 1.9856
# Epoch 5/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 318ms/step - accuracy: 0.1613 - loss: 1.9958 - val_accuracy: 0.3077 - val_loss: 1.9515
# Epoch 6/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 326ms/step - accuracy: 0.2446 - loss: 1.9803 - val_accuracy: 0.3846 - val_loss: 1.9170
# Epoch 7/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 251ms/step - accuracy: 0.2271 - loss: 1.9381 - val_accuracy: 0.3846 - val_loss: 1.8530
# Epoch 8/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 226ms/step - accuracy: 0.2298 - loss: 1.9637 - val_accuracy: 0.5385 - val_loss: 1.7427
# Epoch 9/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 354ms/step - accuracy: 0.4761 - loss: 1.7984 - val_accuracy: 0.4615 - val_loss: 1.6046
# Epoch 10/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 245ms/step - accuracy: 0.5065 - loss: 1.7361 - val_accuracy: 0.3846 - val_loss: 1.4248
# Epoch 11/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 247ms/step - accuracy: 0.3264 - loss: 1.6216 - val_accuracy: 0.7692 - val_loss: 1.2301
# Epoch 12/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 328ms/step - accuracy: 0.4063 - loss: 1.5061 - val_accuracy: 0.7692 - val_loss: 1.0410
# Epoch 13/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 242ms/step - accuracy: 0.3734 - loss: 1.4860 - val_accuracy: 0.5385 - val_loss: 1.0923
# Epoch 14/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 328ms/step - accuracy: 0.5590 - loss: 1.2271 - val_accuracy: 1.0000 - val_loss: 0.8302
# Epoch 15/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 252ms/step - accuracy: 0.5978 - loss: 1.1825 - val_accuracy: 1.0000 - val_loss: 0.7569
# Epoch 16/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 318ms/step - accuracy: 0.6333 - loss: 1.0902 - val_accuracy: 0.6154 - val_loss: 0.8986
# Epoch 17/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 256ms/step - accuracy: 0.6605 - loss: 0.9965 - val_accuracy: 1.0000 - val_loss: 0.5880
# Epoch 18/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 366ms/step - accuracy: 0.7337 - loss: 0.9777 - val_accuracy: 0.8462 - val_loss: 0.5775
# Epoch 19/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 543ms/step - accuracy: 0.6505 - loss: 0.8828 - val_accuracy: 0.8462 - val_loss: 0.6188
# Epoch 20/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 609ms/step - accuracy: 0.7599 - loss: 0.7554 - val_accuracy: 1.0000 - val_loss: 0.3209
# Epoch 21/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 558ms/step - accuracy: 0.8342 - loss: 0.7011 - val_accuracy: 1.0000 - val_loss: 0.2264
# Epoch 22/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 565ms/step - accuracy: 0.7730 - loss: 0.8070 - val_accuracy: 1.0000 - val_loss: 0.2995
# Epoch 23/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 320ms/step - accuracy: 0.7509 - loss: 0.6737 - val_accuracy: 0.8462 - val_loss: 0.4605
# Epoch 24/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 229ms/step - accuracy: 0.6893 - loss: 0.6659 - val_accuracy: 1.0000 - val_loss: 0.0854
# Epoch 25/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 318ms/step - accuracy: 0.8338 - loss: 0.4781 - val_accuracy: 1.0000 - val_loss: 0.1129
# Epoch 26/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 233ms/step - accuracy: 0.7494 - loss: 0.6230 - val_accuracy: 0.8462 - val_loss: 0.3555
# Epoch 27/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 231ms/step - accuracy: 0.8538 - loss: 0.4627 - val_accuracy: 1.0000 - val_loss: 0.2110
# Epoch 28/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 240ms/step - accuracy: 0.7702 - loss: 0.5321 - val_accuracy: 1.0000 - val_loss: 0.0789
# Epoch 29/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 227ms/step - accuracy: 0.7937 - loss: 0.5243 - val_accuracy: 1.0000 - val_loss: 0.0688
# Epoch 30/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 240ms/step - accuracy: 0.8199 - loss: 0.5222 - val_accuracy: 1.0000 - val_loss: 0.0958
# Epoch 31/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 243ms/step - accuracy: 0.8799 - loss: 0.3723 - val_accuracy: 1.0000 - val_loss: 0.0955
# Epoch 32/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 314ms/step - accuracy: 0.9126 - loss: 0.3527 - val_accuracy: 1.0000 - val_loss: 0.0580
# Epoch 33/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 335ms/step - accuracy: 0.8514 - loss: 0.4137 - val_accuracy: 1.0000 - val_loss: 0.0541
# Epoch 34/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 250ms/step - accuracy: 0.9138 - loss: 0.3276 - val_accuracy: 1.0000 - val_loss: 0.0604
# Epoch 35/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 319ms/step - accuracy: 0.8383 - loss: 0.4872 - val_accuracy: 1.0000 - val_loss: 0.0616
# Epoch 36/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 240ms/step - accuracy: 0.8772 - loss: 0.3853 - val_accuracy: 1.0000 - val_loss: 0.0779
# Epoch 37/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 260ms/step - accuracy: 0.8772 - loss: 0.3833 - val_accuracy: 0.9231 - val_loss: 0.1391
# Epoch 38/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 230ms/step - accuracy: 0.8068 - loss: 0.3623 - val_accuracy: 0.9231 - val_loss: 0.3390
# Epoch 39/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 258ms/step - accuracy: 0.9138 - loss: 0.3339 - val_accuracy: 0.9231 - val_loss: 0.1727
# Epoch 40/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 233ms/step - accuracy: 0.8433 - loss: 0.3780 - val_accuracy: 1.0000 - val_loss: 0.0143
# Epoch 41/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 572ms/step - accuracy: 0.8996 - loss: 0.3038 - val_accuracy: 1.0000 - val_loss: 0.0273
# Epoch 42/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 645ms/step - accuracy: 0.9869 - loss: 0.1175 - val_accuracy: 1.0000 - val_loss: 0.0709
# Epoch 43/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 539ms/step - accuracy: 0.8865 - loss: 0.2658 - val_accuracy: 0.8462 - val_loss: 0.3302
# Epoch 44/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 626ms/step - accuracy: 0.9432 - loss: 0.2196 - val_accuracy: 0.9231 - val_loss: 0.1713
# Epoch 45/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 597ms/step - accuracy: 0.9082 - loss: 0.2480 - val_accuracy: 1.0000 - val_loss: 0.0299
# Epoch 46/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 314ms/step - accuracy: 0.8910 - loss: 0.2874 - val_accuracy: 1.0000 - val_loss: 0.0807
# Epoch 47/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 258ms/step - accuracy: 0.9060 - loss: 0.3623 - val_accuracy: 0.8462 - val_loss: 0.3754
# Epoch 48/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 319ms/step - accuracy: 0.9739 - loss: 0.1882 - val_accuracy: 0.8462 - val_loss: 0.2756
# Epoch 49/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 344ms/step - accuracy: 0.8951 - loss: 0.3243 - val_accuracy: 1.0000 - val_loss: 0.1024
# Epoch 50/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 334ms/step - accuracy: 0.9257 - loss: 0.1770 - val_accuracy: 0.9231 - val_loss: 0.1536

# %%
tr_acc = history.history['accuracy']
tr_loss = history.history['loss']
val_acc = history.history['val_accuracy']
val_loss = history.history['val_loss']
index_loss = np.argmin(val_loss)
val_lowest = val_loss[index_loss]
index_acc = np.argmax(val_acc)
acc_highest = val_acc[index_acc]

Epochs = [i+1 for i in range(len(tr_acc))]
loss_label = f'best epoch= {str(index_loss + 1)}'
acc_label = f'best epoch= {str(index_acc + 1)}'

# Plot training history
plt.figure(figsize= (20, 8))
plt.style.use('fivethirtyeight')

plt.subplot(1, 2, 1)
plt.plot(Epochs, tr_loss, 'r', label= 'Training loss')
plt.plot(Epochs, val_loss, 'g', label= 'Validation loss')
plt.scatter(index_loss + 1, val_lowest, s= 150, c= 'blue', label= loss_label)
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(Epochs, tr_acc, 'r', label= 'Training Accuracy')
plt.plot(Epochs, val_acc, 'g', label= 'Validation Accuracy')
plt.scatter(index_acc + 1 , acc_highest, s= 150, c= 'blue', label= acc_label)
plt.title('Training and Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

plt.tight_layout
plt.show()

# %%
# Evaluate the model on the test set
test_loss, test_accuracy = model.evaluate(X_test, y_test, verbose=2)

print(f"Test Loss: {test_loss}")
print(f"Test Accuracy: {test_accuracy}")
# Out:
# 1/1 - 0s - 75ms/step - accuracy: 0.9231 - loss: 0.1536
# Test Loss: 0.15362438559532166
# Test Accuracy: 0.9230769276618958

# %%
from sklearn.metrics import classification_report

# Make predictions on the test set
predictions = model.predict(X_test)
predicted_labels = np.argmax(predictions, axis=1)

# Print classification report
print(classification_report(y_test, predicted_labels, target_names=EMOTIONS))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step
#               precision    recall  f1-score   support
#
#        Anger       1.00      1.00      1.00         2
#     Contempt       1.00      1.00      1.00         2
#      Disgust       1.00      1.00      1.00         1
#         Fear       0.50      1.00      0.67         1
#        Happy       1.00      1.00      1.00         1
#      Neutral       1.00      0.50      0.67         2
#          Sad       1.00      1.00      1.00         1
#    Surprised       1.00      1.00      1.00         3
#
#     accuracy                           0.92        13
#    macro avg       0.94      0.94      0.92        13
# weighted avg       0.96      0.92      0.92        13

# %%
# Make predictions on the test set
predictions = model.predict(X_test)
predicted_labels = np.argmax(predictions, axis=1)

# Generate the confusion matrix
cm = confusion_matrix(y_test, predicted_labels)

# Plot the confusion matrix
plt.figure(figsize=(10, 8))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=EMOTIONS, yticklabels=EMOTIONS)
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.title('Confusion Matrix')
plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 280ms/step

# %%
import matplotlib.pyplot as plt

# Make predictions on the test set
predictions = model.predict(X_test)
predicted_labels = np.argmax(predictions, axis=1)

# Function to display images with predicted and actual labels
def display_images(images, actual_labels, predicted_labels, emotions, num_images=10):
    plt.figure(figsize=(20, 10))
    for i in range(num_images):
        plt.subplot(2, 5, i + 1)
        # Since the images are grayscale, we reshape them to (48, 48)
        img = images[i].reshape(IMG_SIZE, IMG_SIZE)
        plt.imshow(img, cmap='gray')
        plt.title(f"Actual: {emotions[actual_labels[i]]}\nPredicted: {emotions[predicted_labels[i]]}")
        plt.axis('off')
    plt.show()

# Display the images with predicted and actual labels
display_images(X_test, y_test, predicted_labels, EMOTIONS)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step
